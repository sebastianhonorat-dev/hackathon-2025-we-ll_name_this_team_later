# %%
import requests
import pandas as pd
import time
import os

headers = {'User-Agent': 'Bianca Poggi bpoggialways@gmail.com'}  # Replace with your info

# --- Config ---
year = 2023  # Fetch one year at a time
quarters = [1, 2, 3, 4]

xbrl_tags = [
    "Assets", "AssetsCurrent", "AssetsNoncurrent", "CashAndCashEquivalentsAtCarryingValue",
    "MarketableSecurities", "AccountsReceivableNetCurrent", "InventoryNet", "PrepaidExpenseAndOtherAssetsCurrent",
    "PropertyPlantAndEquipmentNet", "Goodwill", "IntangibleAssetsNetExcludingGoodwill",
    "DeferredTaxAssetsNetNoncurrent", "OtherAssetsNoncurrent", "Liabilities", "LiabilitiesCurrent",
    "LiabilitiesNoncurrent", "AccountsPayableCurrent", "AccruedLiabilitiesCurrent", "DeferredRevenueCurrent",
    "ShortTermBorrowings", "LongTermDebtCurrent", "LongTermDebtNoncurrent",
    "DeferredTaxLiabilitiesNoncurrent", "PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent",
    "StockholdersEquity", "CommonStockValue", "AdditionalPaidInCapital", "RetainedEarningsAccumulatedDeficit",
    "TreasuryStockValue", "AccumulatedOtherComprehensiveIncomeLossNetOfTax", "Revenues",
    "RevenueFromContractWithCustomerExcludingAssessedTax", "SalesRevenueNet",
    "RevenueFromContractWithCustomerIncludingAssessedTax", "CostOfRevenue", "CostOfGoodsAndServicesSold",
    "GrossProfit", "OperatingExpenses", "ResearchAndDevelopmentExpense", "SellingGeneralAndAdministrativeExpense",
    "SellingAndMarketingExpense", "GeneralAndAdministrativeExpense", "DepreciationAndAmortization",
    "RestructuringCharges", "OperatingIncomeLoss", "NonoperatingIncomeExpense", "InterestExpense",
    "InterestIncomeExpenseNet", "IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest",
    "IncomeTaxExpenseBenefit", "NetIncomeLoss", "NetIncomeLossAvailableToCommonStockholdersBasic",
    "NetCashProvidedByUsedInOperatingActivities", "DepreciationDepletionAndAmortization",
    "ShareBasedCompensation", "DeferredIncomeTaxExpenseBenefit", "IncreaseDecreaseInAccountsReceivable",
    "IncreaseDecreaseInInventories", "IncreaseDecreaseInAccountsPayable", "NetCashProvidedByUsedInInvestingActivities",
    "PaymentsToAcquirePropertyPlantAndEquipment", "PaymentsToAcquireBusinessesNetOfCashAcquired",
    "PaymentsToAcquireMarketableSecurities", "ProceedsFromSaleOfPropertyPlantAndEquipment",
    "NetCashProvidedByUsedInFinancingActivities", "RepaymentsOfLongTermDebt", "ProceedsFromIssuanceOfLongTermDebt",
    "ProceedsFromIssuanceOfCommonStock", "PaymentsForRepurchaseOfCommonStock", "PaymentsOfDividends",
    "EarningsPerShareBasic", "EarningsPerShareDiluted", "WeightedAverageNumberOfSharesOutstandingBasic",
    "WeightedAverageNumberOfDilutedSharesOutstanding", "CommonStockSharesOutstanding", "CommonStockSharesIssued",
    "ComprehensiveIncomeNetOfTax", "StockIssuedDuringPeriodValueStockOptionsExercised",
    "EffectiveIncomeTaxRateContinuingOperations", "NumberOfOperatingSegments",
    "RevenueFromExternalCustomersByGeographicAreasTableTextBlock"
]

unit = 'USD'
form_types = ['3','4','5','8-K','10-K','10-Q','13D','13G','S-1']

output_file = '/workspaces/hackathon-2025-we-ll_name_this_team_later/project/data/sec_xbrl_merged.csv'

# --- Collect XBRL Data ---
xbrl_records = []
for tag in xbrl_tags:
    for q in quarters:
        url = f'https://data.sec.gov/api/xbrl/frames/us-gaap/{tag}/{unit}/CY{year}Q{q}I.json'
        try:
            r = requests.get(url, headers=headers, timeout=10)
            if r.status_code == 200:
                data = r.json()
                for row in data.get('data', []):
                    xbrl_records.append({
                        'cik': str(row.get('cik','')),  # Convert to string here
                        'period': f'{year}Q{q}',
                        'tag': tag,
                        'value': row.get('val', None)
                    })
                print(f"{tag} {year}Q{q} ✓ {len(data.get('data', []))} records")
            else:
                print(f"{tag} {year}Q{q} ✗ HTTP {r.status_code}")
        except Exception as e:
            print(f"{tag} {year}Q{q} ✗ {str(e)[:30]}")
        time.sleep(0.11)

df_xbrl = pd.DataFrame(xbrl_records)
if not df_xbrl.empty:
    df_xbrl = df_xbrl.pivot_table(index=['cik','period'], columns='tag', values='value').reset_index()

# --- Collect SEC Filings ---
filing_records = []
for form in form_types:
    for q in quarters:
        start_month = (q-1)*3 + 1
        end_month = q*3
        url = "https://efts.sec.gov/LATEST/search-index"
        params = {
            'category':'form-cat',
            'forms':form,
            'startdt':f'{year}-{start_month:02d}-01',
            'enddt':f'{year}-{end_month:02d}-31',
            'from':0,
            'size':1000
        }
        try:
            r = requests.get(url, params=params, headers=headers, timeout=10)
            if r.status_code == 200:
                hits = r.json().get('hits', {}).get('hits', [])
                for hit in hits:
                    src = hit.get('_source', {})
                    filing_records.append({
                        'cik': str(src.get('ciks',[''])[0]),  # Convert to string here too
                        'period': f'{year}Q{q}',
                        'form_type': form,
                        'company_name': src.get('display_names',[''])[0],
                        'filing_date': src.get('file_date',''),
                        'accession_number': src.get('accession_number','')
                    })
                print(f"{form} {year}Q{q} ✓ {len(hits)} filings")
        except Exception as e:
            print(f"{form} {year}Q{q} ✗ {str(e)[:30]}")
        time.sleep(0.11)

df_filings = pd.DataFrame(filing_records)

# --- Merge XBRL and Filings ---
df_merged = pd.merge(df_filings, df_xbrl, on=['cik','period'], how='left') if not df_xbrl.empty else df_filings

# --- Save / Append to CSV ---
os.makedirs(os.path.dirname(output_file), exist_ok=True)
df_merged.to_csv(output_file, mode='a', header=not os.path.exists(output_file), index=False)
print(f"\nData for {year} appended to CSV: {output_file} ({len(df_merged)} rows)")
# Out:
# Assets 2023Q1 ✓ 6284 records
# Assets 2023Q2 ✓ 6303 records
# Assets 2023Q3 ✓ 6096 records
# Assets 2023Q4 ✓ 6414 records
# AssetsCurrent 2023Q1 ✓ 5049 records
# AssetsCurrent 2023Q2 ✓ 5056 records
# AssetsCurrent 2023Q3 ✓ 4849 records
# AssetsCurrent 2023Q4 ✓ 5134 records
# AssetsNoncurrent 2023Q1 ✓ 475 records
# AssetsNoncurrent 2023Q2 ✓ 538 records
# AssetsNoncurrent 2023Q3 ✓ 476 records
# AssetsNoncurrent 2023Q4 ✓ 764 records
# CashAndCashEquivalentsAtCarryingValue 2023Q1 ✓ 5083 records
# CashAndCashEquivalentsAtCarryingValue 2023Q2 ✓ 5113 records
# CashAndCashEquivalentsAtCarryingValue 2023Q3 ✓ 4926 records
# CashAndCashEquivalentsAtCarryingValue 2023Q4 ✓ 5314 records
# MarketableSecurities 2023Q1 ✓ 228 records
# MarketableSecurities 2023Q2 ✓ 232 records
# MarketableSecurities 2023Q3 ✓ 227 records
# MarketableSecurities 2023Q4 ✓ 277 records
# AccountsReceivableNetCurrent 2023Q1 ✓ 3078 records
# AccountsReceivableNetCurrent 2023Q2 ✓ 3116 records
# AccountsReceivableNetCurrent 2023Q3 ✓ 3000 records
# AccountsReceivableNetCurrent 2023Q4 ✓ 3375 records
# InventoryNet 2023Q1 ✓ 2482 records
# InventoryNet 2023Q2 ✓ 2540 records
# InventoryNet 2023Q3 ✓ 2459 records
# InventoryNet 2023Q4 ✓ 2703 records
# PrepaidExpenseAndOtherAssetsCurrent 2023Q1 ✓ 2666 records
# PrepaidExpenseAndOtherAssetsCurrent 2023Q2 ✓ 2703 records
# PrepaidExpenseAndOtherAssetsCurrent 2023Q3 ✓ 2604 records
# PrepaidExpenseAndOtherAssetsCurrent 2023Q4 ✓ 2948 records
# PropertyPlantAndEquipmentNet 2023Q1 ✓ 4326 records
# PropertyPlantAndEquipmentNet 2023Q2 ✓ 4377 records
# PropertyPlantAndEquipmentNet 2023Q3 ✓ 4230 records
# PropertyPlantAndEquipmentNet 2023Q4 ✓ 4661 records
# Goodwill 2023Q1 ✓ 2852 records
# Goodwill 2023Q2 ✓ 2878 records
# Goodwill 2023Q3 ✓ 2834 records
# Goodwill 2023Q4 ✓ 3100 records
# IntangibleAssetsNetExcludingGoodwill 2023Q1 ✓ 2204 records
# IntangibleAssetsNetExcludingGoodwill 2023Q2 ✓ 2250 records
# IntangibleAssetsNetExcludingGoodwill 2023Q3 ✓ 2202 records
# IntangibleAssetsNetExcludingGoodwill 2023Q4 ✓ 2525 records
# DeferredTaxAssetsNetNoncurrent 2023Q1 ✗ HTTP 404
# DeferredTaxAssetsNetNoncurrent 2023Q2 ✗ HTTP 404
# DeferredTaxAssetsNetNoncurrent 2023Q3 ✗ HTTP 404
# DeferredTaxAssetsNetNoncurrent 2023Q4 ✗ HTTP 404
# OtherAssetsNoncurrent 2023Q1 ✓ 3184 records
# OtherAssetsNoncurrent 2023Q2 ✓ 3176 records
# OtherAssetsNoncurrent 2023Q3 ✓ 3111 records
# OtherAssetsNoncurrent 2023Q4 ✓ 3399 records
# Liabilities 2023Q1 ✓ 5555 records
# Liabilities 2023Q2 ✓ 5566 records
# Liabilities 2023Q3 ✓ 5391 records
# Liabilities 2023Q4 ✓ 5733 records
# LiabilitiesCurrent 2023Q1 ✓ 5035 records
# LiabilitiesCurrent 2023Q2 ✓ 5032 records
# LiabilitiesCurrent 2023Q3 ✓ 4839 records
# LiabilitiesCurrent 2023Q4 ✓ 5135 records
# LiabilitiesNoncurrent 2023Q1 ✓ 816 records
# LiabilitiesNoncurrent 2023Q2 ✓ 880 records
# LiabilitiesNoncurrent 2023Q3 ✓ 804 records
# LiabilitiesNoncurrent 2023Q4 ✓ 1089 records
# AccountsPayableCurrent 2023Q1 ✓ 3764 records
# AccountsPayableCurrent 2023Q2 ✓ 3731 records
# AccountsPayableCurrent 2023Q3 ✓ 3581 records
# AccountsPayableCurrent 2023Q4 ✓ 3899 records
# AccruedLiabilitiesCurrent 2023Q1 ✓ 2570 records
# AccruedLiabilitiesCurrent 2023Q2 ✓ 2549 records
# AccruedLiabilitiesCurrent 2023Q3 ✓ 2437 records
# AccruedLiabilitiesCurrent 2023Q4 ✓ 2707 records
# DeferredRevenueCurrent 2023Q1 ✓ 467 records
# DeferredRevenueCurrent 2023Q2 ✓ 501 records
# DeferredRevenueCurrent 2023Q3 ✓ 465 records
# DeferredRevenueCurrent 2023Q4 ✓ 616 records
# ShortTermBorrowings 2023Q1 ✓ 567 records
# ShortTermBorrowings 2023Q2 ✓ 594 records
# ShortTermBorrowings 2023Q3 ✓ 576 records
# ShortTermBorrowings 2023Q4 ✓ 782 records
# LongTermDebtCurrent 2023Q1 ✓ 1291 records
# LongTermDebtCurrent 2023Q2 ✓ 1309 records
# LongTermDebtCurrent 2023Q3 ✓ 1279 records
# LongTermDebtCurrent 2023Q4 ✓ 1542 records
# LongTermDebtNoncurrent 2023Q1 ✓ 1686 records
# LongTermDebtNoncurrent 2023Q2 ✓ 1703 records
# LongTermDebtNoncurrent 2023Q3 ✓ 1642 records
# LongTermDebtNoncurrent 2023Q4 ✓ 1869 records
# DeferredTaxLiabilitiesNoncurrent 2023Q1 ✗ HTTP 404
# DeferredTaxLiabilitiesNoncurrent 2023Q2 ✗ HTTP 404
# DeferredTaxLiabilitiesNoncurrent 2023Q3 ✗ HTTP 404
# DeferredTaxLiabilitiesNoncurrent 2023Q4 ✗ HTTP 404
# PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent 2023Q1 ✓ 287 records
# PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent 2023Q2 ✓ 287 records
# PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent 2023Q3 ✓ 280 records
# PensionAndOtherPostretirementDefinedBenefitPlansLiabilitiesNoncurrent 2023Q4 ✓ 376 records
# StockholdersEquity 2023Q1 ✓ 6172 records
# StockholdersEquity 2023Q2 ✓ 6139 records
# StockholdersEquity 2023Q3 ✓ 5885 records
# StockholdersEquity 2023Q4 ✓ 6185 records
# CommonStockValue 2023Q1 ✓ 4944 records
# CommonStockValue 2023Q2 ✓ 4944 records
# CommonStockValue 2023Q3 ✓ 4777 records
# CommonStockValue 2023Q4 ✓ 5041 records
# AdditionalPaidInCapital 2023Q1 ✓ 3508 records
# AdditionalPaidInCapital 2023Q2 ✓ 3525 records
# AdditionalPaidInCapital 2023Q3 ✓ 3389 records
# AdditionalPaidInCapital 2023Q4 ✓ 3696 records
# RetainedEarningsAccumulatedDeficit 2023Q1 ✓ 5978 records
# RetainedEarningsAccumulatedDeficit 2023Q2 ✓ 6004 records
# RetainedEarningsAccumulatedDeficit 2023Q3 ✓ 5807 records
# RetainedEarningsAccumulatedDeficit 2023Q4 ✓ 6144 records
# TreasuryStockValue 2023Q1 ✓ 1006 records
# TreasuryStockValue 2023Q2 ✓ 935 records
# TreasuryStockValue 2023Q3 ✓ 891 records
# TreasuryStockValue 2023Q4 ✓ 999 records
# AccumulatedOtherComprehensiveIncomeLossNetOfTax 2023Q1 ✓ 3649 records
# AccumulatedOtherComprehensiveIncomeLossNetOfTax 2023Q2 ✓ 3690 records
# AccumulatedOtherComprehensiveIncomeLossNetOfTax 2023Q3 ✓ 3601 records
# AccumulatedOtherComprehensiveIncomeLossNetOfTax 2023Q4 ✓ 4004 records
# Revenues 2023Q1 ✓ 5 records
# Revenues 2023Q2 ✓ 5 records
# Revenues 2023Q3 ✓ 2 records
# Revenues 2023Q4 ✓ 5 records
# RevenueFromContractWithCustomerExcludingAssessedTax 2023Q1 ✗ HTTP 404
# RevenueFromContractWithCustomerExcludingAssessedTax 2023Q2 ✓ 4 records
# RevenueFromContractWithCustomerExcludingAssessedTax 2023Q3 ✓ 1 records
# RevenueFromContractWithCustomerExcludingAssessedTax 2023Q4 ✓ 1 records
# SalesRevenueNet 2023Q1 ✗ HTTP 404
# SalesRevenueNet 2023Q2 ✗ HTTP 404
# SalesRevenueNet 2023Q3 ✗ HTTP 404
# SalesRevenueNet 2023Q4 ✗ HTTP 404
# RevenueFromContractWithCustomerIncludingAssessedTax 2023Q1 ✗ HTTP 404
# RevenueFromContractWithCustomerIncludingAssessedTax 2023Q2 ✗ HTTP 404
# RevenueFromContractWithCustomerIncludingAssessedTax 2023Q3 ✗ HTTP 404
# RevenueFromContractWithCustomerIncludingAssessedTax 2023Q4 ✓ 2 records
# CostOfRevenue 2023Q1 ✗ HTTP 404
# CostOfRevenue 2023Q2 ✓ 1 records
# CostOfRevenue 2023Q3 ✓ 1 records
# CostOfRevenue 2023Q4 ✓ 2 records
# CostOfGoodsAndServicesSold 2023Q1 ✗ HTTP 404
# CostOfGoodsAndServicesSold 2023Q2 ✓ 2 records
# CostOfGoodsAndServicesSold 2023Q3 ✓ 1 records
# CostOfGoodsAndServicesSold 2023Q4 ✓ 2 records
# GrossProfit 2023Q1 ✓ 1 records
# GrossProfit 2023Q2 ✓ 4 records
# GrossProfit 2023Q3 ✓ 1 records
# GrossProfit 2023Q4 ✓ 3 records
# OperatingExpenses 2023Q1 ✓ 6 records
# OperatingExpenses 2023Q2 ✓ 9 records
# OperatingExpenses 2023Q3 ✓ 3 records
# OperatingExpenses 2023Q4 ✓ 11 records
# ResearchAndDevelopmentExpense 2023Q1 ✓ 3 records
# ResearchAndDevelopmentExpense 2023Q2 ✓ 4 records
# ResearchAndDevelopmentExpense 2023Q3 ✗ HTTP 404
# ResearchAndDevelopmentExpense 2023Q4 ✓ 2 records
# SellingGeneralAndAdministrativeExpense 2023Q1 ✗ HTTP 404
# SellingGeneralAndAdministrativeExpense 2023Q2 ✓ 2 records
# SellingGeneralAndAdministrativeExpense 2023Q3 ✓ 1 records
# SellingGeneralAndAdministrativeExpense 2023Q4 ✓ 3 records
# SellingAndMarketingExpense 2023Q1 ✗ HTTP 404
# SellingAndMarketingExpense 2023Q2 ✓ 1 records
# SellingAndMarketingExpense 2023Q3 ✓ 1 records
# SellingAndMarketingExpense 2023Q4 ✗ HTTP 404
# GeneralAndAdministrativeExpense 2023Q1 ✓ 3 records
# GeneralAndAdministrativeExpense 2023Q2 ✓ 5 records
# GeneralAndAdministrativeExpense 2023Q3 ✓ 3 records
# GeneralAndAdministrativeExpense 2023Q4 ✓ 7 records
# DepreciationAndAmortization 2023Q1 ✓ 1 records
# DepreciationAndAmortization 2023Q2 ✓ 1 records
# DepreciationAndAmortization 2023Q3 ✗ HTTP 404
# DepreciationAndAmortization 2023Q4 ✓ 2 records
# RestructuringCharges 2023Q1 ✓ 6 records
# RestructuringCharges 2023Q2 ✓ 4 records
# RestructuringCharges 2023Q3 ✓ 2 records
# RestructuringCharges 2023Q4 ✓ 3 records
# OperatingIncomeLoss 2023Q1 ✓ 6 records
# OperatingIncomeLoss 2023Q2 ✓ 6 records
# OperatingIncomeLoss 2023Q3 ✓ 2 records
# OperatingIncomeLoss 2023Q4 ✓ 12 records
# NonoperatingIncomeExpense 2023Q1 ✗ HTTP 404
# NonoperatingIncomeExpense 2023Q2 ✓ 3 records
# NonoperatingIncomeExpense 2023Q3 ✓ 1 records
# NonoperatingIncomeExpense 2023Q4 ✓ 4 records
# InterestExpense 2023Q1 ✓ 2 records
# InterestExpense 2023Q2 ✓ 3 records
# InterestExpense 2023Q3 ✓ 4 records
# InterestExpense 2023Q4 ✓ 8 records
# InterestIncomeExpenseNet 2023Q1 ✓ 1 records
# InterestIncomeExpenseNet 2023Q2 ✗ HTTP 404
# InterestIncomeExpenseNet 2023Q3 ✗ HTTP 404
# InterestIncomeExpenseNet 2023Q4 ✓ 1 records
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest 2023Q1 ✓ 2 records
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest 2023Q2 ✓ 4 records
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest 2023Q3 ✓ 3 records
# IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest 2023Q4 ✓ 7 records
# IncomeTaxExpenseBenefit 2023Q1 ✓ 4 records
# IncomeTaxExpenseBenefit 2023Q2 ✓ 6 records
# IncomeTaxExpenseBenefit 2023Q3 ✓ 2 records
# IncomeTaxExpenseBenefit 2023Q4 ✓ 5 records
# NetIncomeLoss 2023Q1 ✓ 12 records
# NetIncomeLoss 2023Q2 ✓ 12 records
# NetIncomeLoss 2023Q3 ✓ 8 records
# NetIncomeLoss 2023Q4 ✓ 23 records
# NetIncomeLossAvailableToCommonStockholdersBasic 2023Q1 ✓ 2 records
# NetIncomeLossAvailableToCommonStockholdersBasic 2023Q2 ✓ 3 records
# NetIncomeLossAvailableToCommonStockholdersBasic 2023Q3 ✗ HTTP 404
# NetIncomeLossAvailableToCommonStockholdersBasic 2023Q4 ✓ 2 records
# NetCashProvidedByUsedInOperatingActivities 2023Q1 ✓ 4 records
# NetCashProvidedByUsedInOperatingActivities 2023Q2 ✓ 6 records
# NetCashProvidedByUsedInOperatingActivities 2023Q3 ✓ 2 records
# NetCashProvidedByUsedInOperatingActivities 2023Q4 ✓ 10 records
# DepreciationDepletionAndAmortization 2023Q1 ✗ HTTP 404
# DepreciationDepletionAndAmortization 2023Q2 ✓ 1 records
# DepreciationDepletionAndAmortization 2023Q3 ✗ HTTP 404
# DepreciationDepletionAndAmortization 2023Q4 ✓ 1 records
# ShareBasedCompensation 2023Q1 ✓ 5 records
# ShareBasedCompensation 2023Q2 ✓ 6 records
# ShareBasedCompensation 2023Q3 ✓ 2 records
# ShareBasedCompensation 2023Q4 ✓ 6 records
# DeferredIncomeTaxExpenseBenefit 2023Q1 ✗ HTTP 404
# DeferredIncomeTaxExpenseBenefit 2023Q2 ✓ 3 records
# DeferredIncomeTaxExpenseBenefit 2023Q3 ✓ 1 records
# DeferredIncomeTaxExpenseBenefit 2023Q4 ✓ 3 records
# IncreaseDecreaseInAccountsReceivable 2023Q1 ✗ HTTP 404
# IncreaseDecreaseInAccountsReceivable 2023Q2 ✓ 2 records
# IncreaseDecreaseInAccountsReceivable 2023Q3 ✓ 1 records
# IncreaseDecreaseInAccountsReceivable 2023Q4 ✓ 2 records
# IncreaseDecreaseInInventories 2023Q1 ✗ HTTP 404
# IncreaseDecreaseInInventories 2023Q2 ✓ 1 records
# IncreaseDecreaseInInventories 2023Q3 ✗ HTTP 404
# IncreaseDecreaseInInventories 2023Q4 ✓ 1 records
# IncreaseDecreaseInAccountsPayable 2023Q1 ✓ 2 records
# IncreaseDecreaseInAccountsPayable 2023Q2 ✓ 1 records
# IncreaseDecreaseInAccountsPayable 2023Q3 ✗ HTTP 404
# IncreaseDecreaseInAccountsPayable 2023Q4 ✓ 2 records
# NetCashProvidedByUsedInInvestingActivities 2023Q1 ✓ 1 records
# NetCashProvidedByUsedInInvestingActivities 2023Q2 ✓ 3 records
# NetCashProvidedByUsedInInvestingActivities 2023Q3 ✓ 2 records
# NetCashProvidedByUsedInInvestingActivities 2023Q4 ✓ 6 records
# PaymentsToAcquirePropertyPlantAndEquipment 2023Q1 ✓ 3 records
# PaymentsToAcquirePropertyPlantAndEquipment 2023Q2 ✓ 8 records
# PaymentsToAcquirePropertyPlantAndEquipment 2023Q3 ✓ 1 records
# PaymentsToAcquirePropertyPlantAndEquipment 2023Q4 ✓ 4 records
# PaymentsToAcquireBusinessesNetOfCashAcquired 2023Q1 ✓ 3 records
# PaymentsToAcquireBusinessesNetOfCashAcquired 2023Q2 ✓ 6 records
# PaymentsToAcquireBusinessesNetOfCashAcquired 2023Q3 ✓ 1 records
# PaymentsToAcquireBusinessesNetOfCashAcquired 2023Q4 ✓ 2 records
# PaymentsToAcquireMarketableSecurities 2023Q1 ✓ 1 records
# PaymentsToAcquireMarketableSecurities 2023Q2 ✓ 1 records
# PaymentsToAcquireMarketableSecurities 2023Q3 ✓ 1 records
# PaymentsToAcquireMarketableSecurities 2023Q4 ✗ HTTP 404
# ProceedsFromSaleOfPropertyPlantAndEquipment 2023Q1 ✓ 4 records
# ProceedsFromSaleOfPropertyPlantAndEquipment 2023Q2 ✓ 6 records
# ProceedsFromSaleOfPropertyPlantAndEquipment 2023Q3 ✓ 3 records
# ProceedsFromSaleOfPropertyPlantAndEquipment 2023Q4 ✓ 5 records
# NetCashProvidedByUsedInFinancingActivities 2023Q1 ✓ 5 records
# NetCashProvidedByUsedInFinancingActivities 2023Q2 ✓ 6 records
# NetCashProvidedByUsedInFinancingActivities 2023Q3 ✓ 3 records
# NetCashProvidedByUsedInFinancingActivities 2023Q4 ✓ 12 records
# RepaymentsOfLongTermDebt 2023Q1 ✓ 3 records
# RepaymentsOfLongTermDebt 2023Q2 ✓ 7 records
# RepaymentsOfLongTermDebt 2023Q3 ✓ 4 records
# RepaymentsOfLongTermDebt 2023Q4 ✓ 9 records
# ProceedsFromIssuanceOfLongTermDebt 2023Q1 ✓ 1 records
# ProceedsFromIssuanceOfLongTermDebt 2023Q2 ✓ 4 records
# ProceedsFromIssuanceOfLongTermDebt 2023Q3 ✓ 1 records
# ProceedsFromIssuanceOfLongTermDebt 2023Q4 ✓ 1 records
# ProceedsFromIssuanceOfCommonStock 2023Q1 ✓ 51 records
# ProceedsFromIssuanceOfCommonStock 2023Q2 ✓ 52 records
# ProceedsFromIssuanceOfCommonStock 2023Q3 ✓ 48 records
# ProceedsFromIssuanceOfCommonStock 2023Q4 ✓ 58 records
# PaymentsForRepurchaseOfCommonStock 2023Q1 ✓ 5 records
# PaymentsForRepurchaseOfCommonStock 2023Q2 ✓ 10 records
# PaymentsForRepurchaseOfCommonStock 2023Q3 ✓ 4 records
# PaymentsForRepurchaseOfCommonStock 2023Q4 ✓ 9 records
# PaymentsOfDividends 2023Q1 ✓ 16 records
# PaymentsOfDividends 2023Q2 ✓ 20 records
# PaymentsOfDividends 2023Q3 ✓ 16 records
# PaymentsOfDividends 2023Q4 ✓ 16 records
# EarningsPerShareBasic 2023Q1 ✗ HTTP 404
# EarningsPerShareBasic 2023Q2 ✗ HTTP 404
# EarningsPerShareBasic 2023Q3 ✗ HTTP 404
# EarningsPerShareBasic 2023Q4 ✗ HTTP 404
# EarningsPerShareDiluted 2023Q1 ✗ HTTP 404
# EarningsPerShareDiluted 2023Q2 ✗ HTTP 404
# EarningsPerShareDiluted 2023Q3 ✗ HTTP 404
# EarningsPerShareDiluted 2023Q4 ✗ HTTP 404
# WeightedAverageNumberOfSharesOutstandingBasic 2023Q1 ✗ HTTP 404
# WeightedAverageNumberOfSharesOutstandingBasic 2023Q2 ✗ HTTP 404
# WeightedAverageNumberOfSharesOutstandingBasic 2023Q3 ✗ HTTP 404
# WeightedAverageNumberOfSharesOutstandingBasic 2023Q4 ✗ HTTP 404
# WeightedAverageNumberOfDilutedSharesOutstanding 2023Q1 ✗ HTTP 404
# WeightedAverageNumberOfDilutedSharesOutstanding 2023Q2 ✗ HTTP 404
# WeightedAverageNumberOfDilutedSharesOutstanding 2023Q3 ✗ HTTP 404
# WeightedAverageNumberOfDilutedSharesOutstanding 2023Q4 ✗ HTTP 404
# CommonStockSharesOutstanding 2023Q1 ✗ HTTP 404
# CommonStockSharesOutstanding 2023Q2 ✗ HTTP 404
# CommonStockSharesOutstanding 2023Q3 ✗ HTTP 404
# CommonStockSharesOutstanding 2023Q4 ✗ HTTP 404
# CommonStockSharesIssued 2023Q1 ✗ HTTP 404
# CommonStockSharesIssued 2023Q2 ✗ HTTP 404
# CommonStockSharesIssued 2023Q3 ✗ HTTP 404
# CommonStockSharesIssued 2023Q4 ✗ HTTP 404
# ComprehensiveIncomeNetOfTax 2023Q1 ✗ HTTP 404
# ComprehensiveIncomeNetOfTax 2023Q2 ✓ 4 records
# ComprehensiveIncomeNetOfTax 2023Q3 ✓ 2 records
# ComprehensiveIncomeNetOfTax 2023Q4 ✓ 2 records
# StockIssuedDuringPeriodValueStockOptionsExercised 2023Q1 ✓ 2 records
# StockIssuedDuringPeriodValueStockOptionsExercised 2023Q2 ✓ 3 records
# StockIssuedDuringPeriodValueStockOptionsExercised 2023Q3 ✓ 1 records
# StockIssuedDuringPeriodValueStockOptionsExercised 2023Q4 ✓ 6 records
# EffectiveIncomeTaxRateContinuingOperations 2023Q1 ✗ HTTP 404
# EffectiveIncomeTaxRateContinuingOperations 2023Q2 ✗ HTTP 404
# EffectiveIncomeTaxRateContinuingOperations 2023Q3 ✗ HTTP 404
# EffectiveIncomeTaxRateContinuingOperations 2023Q4 ✗ HTTP 404
# NumberOfOperatingSegments 2023Q1 ✗ HTTP 404
# NumberOfOperatingSegments 2023Q2 ✗ HTTP 404
# NumberOfOperatingSegments 2023Q3 ✗ HTTP 404
# NumberOfOperatingSegments 2023Q4 ✗ HTTP 404
# RevenueFromExternalCustomersByGeographicAreasTableTextBlock 2023Q1 ✗ HTTP 404
# RevenueFromExternalCustomersByGeographicAreasTableTextBlock 2023Q2 ✗ HTTP 404
# RevenueFromExternalCustomersByGeographicAreasTableTextBlock 2023Q3 ✗ HTTP 404
# RevenueFromExternalCustomersByGeographicAreasTableTextBlock 2023Q4 ✗ HTTP 404
# 3 2023Q1 ✓ 100 filings
# 3 2023Q2 ✓ 100 filings
# 3 2023Q3 ✓ 100 filings
# 3 2023Q4 ✓ 100 filings
# 4 2023Q1 ✓ 100 filings
# 4 2023Q2 ✓ 100 filings
# 4 2023Q3 ✓ 100 filings
# 4 2023Q4 ✓ 100 filings
# 5 2023Q1 ✓ 100 filings
# 5 2023Q2 ✓ 67 filings
# 5 2023Q3 ✓ 81 filings
# 5 2023Q4 ✓ 98 filings
# 8-K 2023Q1 ✓ 100 filings
# 8-K 2023Q2 ✓ 100 filings
# 8-K 2023Q3 ✓ 100 filings
# 8-K 2023Q4 ✓ 100 filings
# 10-K 2023Q1 ✓ 100 filings
# 10-K 2023Q2 ✓ 100 filings
# 10-K 2023Q3 ✓ 100 filings
# 10-K 2023Q4 ✓ 100 filings
# 10-Q 2023Q1 ✓ 100 filings
# 10-Q 2023Q2 ✓ 100 filings
# 10-Q 2023Q3 ✓ 100 filings
# 10-Q 2023Q4 ✓ 100 filings
# 13D 2023Q1 ✓ 0 filings
# 13D 2023Q2 ✓ 0 filings
# 13D 2023Q3 ✓ 0 filings
# 13D 2023Q4 ✓ 0 filings
# 13G 2023Q1 ✓ 0 filings
# 13G 2023Q2 ✓ 0 filings
# 13G 2023Q3 ✓ 0 filings
# 13G 2023Q4 ✓ 0 filings
# S-1 2023Q1 ✓ 100 filings
# S-1 2023Q2 ✓ 100 filings
# S-1 2023Q3 ✓ 100 filings
# S-1 2023Q4 ✓ 100 filings
#
# Data for 2023 appended to CSV: /workspaces/hackathon-2025-we-ll_name_this_team_later/project/data/sec_xbrl_merged.csv (2746 rows)
